# %% [markdown]
# # Análise do PIB de países com Rede Neural Recorrente (RNN) Predição

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

from matplotlib.colors import ListedColormap
import folium
from folium.plugins import MarkerCluster,HeatMap,HeatMapWithTime
import branca.colormap as colormap
from collections import defaultdict

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import geopandas as gpd
from shapely.geometry import Point

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os
from pathlib import Path

# to make this notebook's output stable across runs
RANDOM_SEED = 42
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# # Where to save the figures
# PROJECT_ROOT_DIR = "."
# CHAPTER_ID = "rnn"
# IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
# os.makedirs(IMAGES_PATH, exist_ok=True)

# def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
#     path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
#     print("Saving figure", fig_id)
#     if tight_layout:
#         plt.tight_layout()
#     plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# No GPU was detected. LSTMs and CNNs can be very slow without a GPU.

# %% [markdown]
# ## Funcoes

# %%
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    # for x in unique_list:
    #     print (x)
    return unique_list

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    # plt.hlines(0, 0, 100, linewidth=1)
    # plt.axis([0, n_steps + 1, -1, 1])

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(
        np.arange(len(val_loss)) + 1,
        val_loss,
        "r.-",
        label="Validation loss",
    )
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 2])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %% [markdown]
# ## Carregando o dataset com os dados dos países

# %%
df_latlong = pd.read_csv('countries.csv')

# %%
df_latlong.drop(['Importance', 'Altitude'], axis=1, inplace=True)
df_latlong.head().T
# Out:
#                      0        1        2        3        4
# Country    Afghanistan  Albania  Algeria  Andorra   Angola
# Latitude        33.768       41       28  42.5407 -11.8776
# Longitude      66.2385       20  2.99998   1.5732  17.5691

# %%
df_gdp = pd.read_csv('gdp_per_capita.csv')

# %%
df_gdp.drop(['Unnamed: 65', 'Code'], axis=1, inplace=True)

# %%
df_gdp.head().T
# Out:
#                     0                            1            2  \
# Country Name    Aruba  Africa Eastern and Southern  Afghanistan
# 1960              NaN                      147.612      59.7732
# 1961              NaN                      147.015      59.8609
# 1962              NaN                      156.189       58.458
# 1963              NaN                      182.244      78.7064
# ...               ...                          ...          ...
# 2016          28452.2                      1431.78      512.013
# 2017          29350.8                      1573.06       516.68
# 2018          30253.3                      1574.98      485.668
# 2019              NaN                      1530.06      494.179
# 2020              NaN                      1359.62      516.748
#
#                                        3        4
# Country Name  Africa Western and Central   Angola
# 1960                             107.932      NaN
# 1961                             113.082      NaN
# 1962                             118.831      NaN
# 1963                             123.443      NaN
# ...                                  ...      ...
# 2016                             1673.84  3506.07
# 2017                             1613.47  4095.81
# 2018                             1704.14  3289.64
# 2019                             1777.92  2809.63
# 2020                             1710.07  1776.17
#
# [62 rows x 5 columns]

# %%
countries_df_latlong = df_latlong['Country'].values
countries_df_gdp = df_gdp['Country Name'].values

mismatch = [i for i in countries_df_latlong if i not in countries_df_gdp]

print(
"countries_df_latlong: ",len(countries_df_latlong),
"\n\ncountries_df_gdp: ",len(countries_df_gdp),
"\n\nmismatch: ",len(mismatch),
"\n\nmismatch countries:", mismatch
)
# Out:
# countries_df_latlong:  184
#
# countries_df_gdp:  266
#
# mismatch:  25
#
# mismatch countries: ['Bahamas', 'Brunei', 'Burma', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Czechia', 'Diamond Princess', 'Egypt', 'Gambia', 'Holy See', 'Iran', 'Korea, South', 'Kyrgyzstan', 'Laos', 'MS Zaandam', 'Russia', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Slovakia', 'Syria', 'Taiwan*', 'US', 'Venezuela', 'Western Sahara']

# %%
#### Depois fazer a correspondencia certinha
nodes = set(countries_df_latlong)-set(mismatch)
len(nodes)
# Out:
# 159

# %%
nodes_df = [i for i in nodes]
df = df_latlong[df_latlong['Country'].isin(nodes_df)]
df.head(5).T
# Out:
#                      0        1        2        3        4
# Country    Afghanistan  Albania  Algeria  Andorra   Angola
# Latitude        33.768       41       28  42.5407 -11.8776
# Longitude      66.2385       20  2.99998   1.5732  17.5691

# %%
df = pd.merge(df_latlong,df_gdp,how='inner',left_on=['Country'],right_on=['Country Name'])

df.drop(['Country Name'], axis=1, inplace=True)
df = df.rename({'Latitude': 'Lat', 'Longitude': 'Lon'}, axis=1)  # new method

df.head().T
# Out:
#                    0        1        2        3        4
# Country  Afghanistan  Albania  Algeria  Andorra   Angola
# Lat           33.768       41       28  42.5407 -11.8776
# Lon          66.2385       20  2.99998   1.5732  17.5691
# 1960         59.7732      NaN  246.304      NaN      NaN
# 1961         59.8609      NaN  214.772      NaN      NaN
# ...              ...      ...      ...      ...      ...
# 2016         512.013  4124.06  3946.45  37475.6  3506.07
# 2017          516.68  4531.02   4109.7  38964.9  4095.81
# 2018         485.668  5287.66  4142.02    41792  3289.64
# 2019         494.179  5395.66  3989.67  40897.3  2809.63
# 2020         516.748  5246.29  3306.86      NaN  1776.17
#
# [64 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Lat', 'Lon', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020'],
#       dtype='object')

# %% [markdown]
# ## Arrumando os dados

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Lat'}>,
#         <AxesSubplot:title={'center':'Lon'}>,
#         <AxesSubplot:title={'center':'1960'}>,
#         <AxesSubplot:title={'center':'1961'}>,
#         <AxesSubplot:title={'center':'1962'}>,
#         <AxesSubplot:title={'center':'1963'}>,
#         <AxesSubplot:title={'center':'1964'}>,
#         <AxesSubplot:title={'center':'1965'}>],
#        [<AxesSubplot:title={'center':'1966'}>,
#         <AxesSubplot:title={'center':'1967'}>,
#         <AxesSubplot:title={'center':'1968'}>,
#         <AxesSubplot:title={'center':'1969'}>,
#         <AxesSubplot:title={'center':'1970'}>,
#         <AxesSubplot:title={'center':'1971'}>,
#         <AxesSubplot:title={'center':'1972'}>,
#         <AxesSubplot:title={'center':'1973'}>],
#        [<AxesSubplot:title={'center':'1974'}>,
#         <AxesSubplot:title={'center':'1975'}>,
#         <AxesSubplot:title={'center':'1976'}>,
#         <AxesSubplot:title={'center':'1977'}>,
#         <AxesSubplot:title={'center':'1978'}>,
#         <AxesSubplot:title={'center':'1979'}>,
#         <AxesSubplot:title={'center':'1980'}>,
#         <AxesSubplot:title={'center':'1981'}>],
#        [<AxesSubplot:title={'center':'1982'}>,
#         <AxesSubplot:title={'center':'1983'}>,
#         <AxesSubplot:title={'center':'1984'}>,
#         <AxesSubplot:title={'center':'1985'}>,
#         <AxesSubplot:title={'center':'1986'}>,
#         <AxesSubplot:title={'center':'1987'}>,
#         <AxesSubplot:title={'center':'1988'}>,
#         <AxesSubplot:title={'center':'1989'}>],
#        [<AxesSubplot:title={'center':'1990'}>,
#         <AxesSubplot:title={'center':'1991'}>,
#         <AxesSubplot:title={'center':'1992'}>,
#         <AxesSubplot:title={'center':'1993'}>,
#         <AxesSubplot:title={'center':'1994'}>,
#         <AxesSubplot:title={'center':'1995'}>,
#         <AxesSubplot:title={'center':'1996'}>,
#         <AxesSubplot:title={'center':'1997'}>],
#        [<AxesSubplot:title={'center':'1998'}>,
#         <AxesSubplot:title={'center':'1999'}>,
#         <AxesSubplot:title={'center':'2000'}>,
#         <AxesSubplot:title={'center':'2001'}>,
#         <AxesSubplot:title={'center':'2002'}>,
#         <AxesSubplot:title={'center':'2003'}>,
#         <AxesSubplot:title={'center':'2004'}>,
#         <AxesSubplot:title={'center':'2005'}>],
#        [<AxesSubplot:title={'center':'2006'}>,
#         <AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>,
#         <AxesSubplot:title={'center':'2009'}>,
#         <AxesSubplot:title={'center':'2010'}>,
#         <AxesSubplot:title={'center':'2011'}>,
#         <AxesSubplot:title={'center':'2012'}>,
#         <AxesSubplot:title={'center':'2013'}>],
#        [<AxesSubplot:title={'center':'2014'}>,
#         <AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>,
#         <AxesSubplot:title={'center':'2017'}>,
#         <AxesSubplot:title={'center':'2018'}>,
#         <AxesSubplot:title={'center':'2019'}>,
#         <AxesSubplot:title={'center':'2020'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
GDP_years = list(set(df.columns) - {'Country', 'Lat', 'Lon'})

# %%
for column in GDP_years:
    df[column] = np.log10(df[column])

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Lat'}>,
#         <AxesSubplot:title={'center':'Lon'}>,
#         <AxesSubplot:title={'center':'1960'}>,
#         <AxesSubplot:title={'center':'1961'}>,
#         <AxesSubplot:title={'center':'1962'}>,
#         <AxesSubplot:title={'center':'1963'}>,
#         <AxesSubplot:title={'center':'1964'}>,
#         <AxesSubplot:title={'center':'1965'}>],
#        [<AxesSubplot:title={'center':'1966'}>,
#         <AxesSubplot:title={'center':'1967'}>,
#         <AxesSubplot:title={'center':'1968'}>,
#         <AxesSubplot:title={'center':'1969'}>,
#         <AxesSubplot:title={'center':'1970'}>,
#         <AxesSubplot:title={'center':'1971'}>,
#         <AxesSubplot:title={'center':'1972'}>,
#         <AxesSubplot:title={'center':'1973'}>],
#        [<AxesSubplot:title={'center':'1974'}>,
#         <AxesSubplot:title={'center':'1975'}>,
#         <AxesSubplot:title={'center':'1976'}>,
#         <AxesSubplot:title={'center':'1977'}>,
#         <AxesSubplot:title={'center':'1978'}>,
#         <AxesSubplot:title={'center':'1979'}>,
#         <AxesSubplot:title={'center':'1980'}>,
#         <AxesSubplot:title={'center':'1981'}>],
#        [<AxesSubplot:title={'center':'1982'}>,
#         <AxesSubplot:title={'center':'1983'}>,
#         <AxesSubplot:title={'center':'1984'}>,
#         <AxesSubplot:title={'center':'1985'}>,
#         <AxesSubplot:title={'center':'1986'}>,
#         <AxesSubplot:title={'center':'1987'}>,
#         <AxesSubplot:title={'center':'1988'}>,
#         <AxesSubplot:title={'center':'1989'}>],
#        [<AxesSubplot:title={'center':'1990'}>,
#         <AxesSubplot:title={'center':'1991'}>,
#         <AxesSubplot:title={'center':'1992'}>,
#         <AxesSubplot:title={'center':'1993'}>,
#         <AxesSubplot:title={'center':'1994'}>,
#         <AxesSubplot:title={'center':'1995'}>,
#         <AxesSubplot:title={'center':'1996'}>,
#         <AxesSubplot:title={'center':'1997'}>],
#        [<AxesSubplot:title={'center':'1998'}>,
#         <AxesSubplot:title={'center':'1999'}>,
#         <AxesSubplot:title={'center':'2000'}>,
#         <AxesSubplot:title={'center':'2001'}>,
#         <AxesSubplot:title={'center':'2002'}>,
#         <AxesSubplot:title={'center':'2003'}>,
#         <AxesSubplot:title={'center':'2004'}>,
#         <AxesSubplot:title={'center':'2005'}>],
#        [<AxesSubplot:title={'center':'2006'}>,
#         <AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>,
#         <AxesSubplot:title={'center':'2009'}>,
#         <AxesSubplot:title={'center':'2010'}>,
#         <AxesSubplot:title={'center':'2011'}>,
#         <AxesSubplot:title={'center':'2012'}>,
#         <AxesSubplot:title={'center':'2013'}>],
#        [<AxesSubplot:title={'center':'2014'}>,
#         <AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>,
#         <AxesSubplot:title={'center':'2017'}>,
#         <AxesSubplot:title={'center':'2018'}>,
#         <AxesSubplot:title={'center':'2019'}>,
#         <AxesSubplot:title={'center':'2020'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df = df.melt(id_vars=['Country', 'Lat', 'Lon'], 
        var_name="Year", 
        value_name="GDP")

# %% [markdown]
# ## Analisando os dados

# %%
df.groupby("Country")['GDP'].count()
# Out:
# Country
# Afghanistan           41
# Albania               37
# Algeria               61
# Andorra               50
# Angola                38
#                       ..
# Uzbekistan            31
# Vietnam               36
# West Bank and Gaza    27
# Zambia                61
# Zimbabwe              61
# Name: GDP, Length: 159, dtype: int64

# %%
data = df.copy()

# %%
data.describe()
# Out:
#                Lat          Lon          GDP
# count  9699.000000  9699.000000  7944.000000
# mean     19.992953    15.263292     3.302753
# std      24.147219    56.528889     0.759844
# min     -41.500083  -107.991707     1.357846
# 25%       4.706435    -7.889626     2.694405
# 50%      18.115296    19.015617     3.252151
# 75%      41.323730    38.652120     3.862819
# max      64.984182   179.012274     5.277580

# %%
data.notna().sum()
# Out:
# Country    9699
# Lat        9699
# Lon        9699
# Year       9699
# GDP        7944
# dtype: int64

# %%
# Convert it to a GeoDataFrame by transforming the Latitude/Longitude coordinates 
loc_crs = {'init': 'epsg:4326'}
loc_geom = [Point(xy) for xy in zip(df['Lon'], df['Lat'])]
geo_df = gpd.GeoDataFrame(df, crs=loc_crs, geometry=loc_geom)

# Plot the GeoDataFrame
geo_df.plot()
# Out:
# c:\Users\User\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <AxesSubplot:>

# %% [markdown]
# ## Arrumando dataset para entrada do modelo

# %%
del df['geometry']
colunas = df.columns.tolist()

# %%
lista_unica = unique(df['Country'].tolist())

# %%
dataset = []
for pais in lista_unica:
   data_pais = df[df["Country"] == pais]
   latitude_pais = data_pais.Lat
   latitude_pais = latitude_pais.tolist()
   latitude_pais = latitude_pais[0]
   longitude_pais = data_pais.Lon
   longitude_pais = longitude_pais.tolist()
   longitude_pais = longitude_pais[0]
   linha = 0
   gdp =  data_pais.GDP
   gdp = gdp.tolist()
 
   while linha<len(gdp)-3: 
    #  dataset_array = []
    
     gdp_1 = gdp[linha]
     gdp_2 = gdp[linha+1]
     gdp_3 = gdp[linha+2]
     gdp_4 = gdp[linha+3]
     gdp_5 = gdp[linha+4]

    #  print("gdp_1 {0}".format(gdp_1))
    #  print("gdp_2 {0}".format(gdp_2))
    #  print("gdp_3 {0}".format(gdp_3))
    #  print("gdp_4 {0}".format(gdp_4))
    #  print("gdp_5 {0}".format(gdp_5))
     if math.isnan(gdp_1) or math.isnan(gdp_2) or math.isnan(gdp_3) or math.isnan(gdp_4) or math.isnan(gdp_5):
       nan = 0
      #  print(gdp_1[0])
      #  print("nan")
     else:
       dataset.append([latitude_pais, longitude_pais, gdp_1, gdp_2, gdp_3, gdp_4, gdp_5])

      
      # dataset.append(dataset_array)
     linha +=4

print(dataset)
# Out:
# [[33.7680065, 66.2385139, 1.77650675159198, 1.7771432420529094, 1.7668440175547175, 1.896010207182971, 1.9143183288048449], [33.7680065, 66.2385139, 1.9143183288048449, 2.0047869164597008, 2.1386004366950297, 2.206551817632813, 2.1109541995868426], [33.7680065, 66.2385139, 2.1109541995868426, 2.11169847286774, 2.194566430088779, 2.2029444653346357, 2.1313530925402], [33.7680065, 66.2385139, 2.1313530925402, 2.1557751194828882, 2.2396838529449705, 2.2707040741998634, 2.2954472567459296], [33.7680065, 66.2385139, 2.2954472567459296, 2.3506840357202976, 2.3933190919676366, 2.440496802935192, 2.435614278936726], [33.7680065, 66.2385139, 2.325068155125743, 2.3838715571348947, 2.4211654660673183, 2.555932176686303, 2.5618923460356995], [33.7680065, 66.2385139, 2.5618923460356995, 2.6407484313155045, 2.735044921794613, 2.7717271015337337, 2.805396079015299], [33.7680065, 66.2385139, 2.805396079015299, 2.7954040857303757, 2.7883263169355805, 2.7450804317977333, 2.7092807996512605], [33.7680065, 66.2385139, 2.7092807996512605, 2.7132215350868445, 2.686339863783303, 2.6938845937210143, 2.713278695849043], [41.000028, 19.9999619, 2.8058301825660266, 2.8060889725944818, 2.8412802856163517, 2.829170815306394, 2.8147630619603885], [41.000028, 19.9999619, 2.8147630619603885, 2.8438526828114825, 2.7904473328975015, 2.5270973311169462, 2.3028766358164767], [41.000028, 19.9999619, 2.3028766358164767, 2.564996363441025, 2.768206062790089, 2.8754111343484285, 3.004311601977297], [41.000028, 19.9999619, 3.004311601977297, 2.8557492936189344, 2.9105120268338047, 3.014202274843047, 3.0518018725961205], [41.000028, 19.9999619, 3.0518018725961205, 3.107772771312948, 3.1538527205564293, 3.2662599556869765, 3.3754041102622585], [41.000028, 19.9999619, 3.3754041102622585, 3.4271267398887013, 3.4731573540362737, 3.555703492155152, 3.6405350918598374], [41.000028, 19.9999619, 3.6405350918598374, 3.6142785277577776, 3.612184793765988, 3.647103387406623, 3.6281466843131116], [41.000028, 19.9999619, 3.6281466843131116, 3.6447400295015084, 3.6607358538205137, 3.596905119739823, 3.6153244896255887], [41.000028, 19.9999619, 3.6153244896255887, 3.656195919142977, 3.723263825395719, 3.732044537719251, 3.7198524844047975], [28.000027199999998, 2.9999825, 2.3914710263942793, 2.331977621155402, 2.2361403429784765, 2.355825787185081, 2.376656711006167], [28.000027199999998, 2.9999825, 2.376656711006167, 2.397737729057904, 2.3721718391785798, 2.404703349757699, 2.4501348003546872], [28.000027199999998, 2.9999825, 2.4501348003546872, 2.4810873990398217, 2.5266296055522965, 2.5332494197583943, 2.646087569751242], [28.000027199999998, 2.9999825, 2.646087569751242, 2.7437393227230666, 2.912757672543503, 2.9716422842003083, 3.0160329598896976], [28.000027199999998, 2.9999825, 3.0160329598896976, 3.0765473231476954, 3.163286454049042, 3.2510780987653716, 3.3430254304841203], [28.000027199999998, 2.9999825, 3.3430254304841203, 3.3496828306461834, 3.3444516236678847, 3.364110966236402, 3.392230070004059], [28.000027199999998, 2.9999825, 3.392230070004059, 3.4121040635388575, 3.4404296744913894, 3.4483203223168126, 3.383344240006452], [28.000027199999998, 2.9999825, 3.383344240006452, 3.3455626758195156, 3.38180488660626, 3.2384529367502086, 3.249449876366274], [28.000027199999998, 2.9999825, 3.249449876366274, 3.257029636045258, 3.1783686998772334, 3.1620498883237937, 3.205188200041178], [28.000027199999998, 2.9999825, 3.205188200041178, 3.209460791006432, 3.2030339552636486, 3.200945908690951, 3.24675138922397], [28.000027199999998, 2.9999825, 3.24675138922397, 3.2407006394816618, 3.250866000550617, 3.3229180066842305, 3.416671359859334], [28.000027199999998, 2.9999825, 3.416671359859334, 3.493192357622781, 3.5414182259256703, 3.5966534945169673, 3.6922855516965587], [28.000027199999998, 2.9999825, 3.6922855516965587, 3.5891976883726353, 3.651354233519857, 3.7368488416002505, 3.747584257283366], [28.000027199999998, 2.9999825, 3.747584257283366, 3.740330102845113, 3.739814081 ...

# %%
my_array = np.array(dataset)
dataset = my_array.astype('float32')
# Normalizando os Valores
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[0.706847  , 0.60706556, 0.07865071, ..., 0.05209646, 0.13729608,
#         0.11500645],
#        [0.706847  , 0.60706556, 0.11500645, ..., 0.15247476, 0.2165213 ,
#         0.16688049],
#        [0.706847  , 0.60706556, 0.16688049, ..., 0.16758627, 0.215601  ,
#         0.17226183],
#        ...,
#        [0.21641307, 0.47991863, 0.28330946, ..., 0.37884116, 0.4288642 ,
#         0.43191355],
#        [0.21641307, 0.47991863, 0.43191355, ..., 0.42740548, 0.45973602,
#         0.44513446],
#        [0.21641307, 0.47991863, 0.44513446, ..., 0.41166365, 0.4494321 ,
#         0.4236831 ]], dtype=float32)

# %%
# dataset_final=[]
# for linha in dataset:
#   linha_final = []
#   for c in linha:
#     linha_final.append([c])
#   dataset_final.append(linha_final)
# my_array = np.array(dataset_final)
# dataset = my_array.astype('float32')
# print(dataset)

# %% [markdown]
# ## Separando em treinamento, validacao e teste

# %%
n_steps = 6 #CADA LISTA DENTRO DA LISTA VAI TER 7 DADOS

setenta_porc= int((70*len(dataset))/100)
vint_poc = int((20*len(dataset))/100)
nov_porc=setenta_porc+vint_poc

X_train, y_train = dataset[:setenta_porc, :n_steps], dataset[:setenta_porc, -1]
X_valid, y_valid = dataset[setenta_porc:nov_porc, :n_steps], dataset[setenta_porc:nov_porc, -1]
X_test, y_test = dataset[nov_porc:, :n_steps], dataset[nov_porc:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((1332, 6), (1332,))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(12, 4))
for col in range(2):
    plt.sca(axes[col])
    plot_series(
        X_valid[col, :],
        y_valid[col],
        y_label=("$x(t)$" if col == 0 else None),
    )
plt.show()

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.00037205196

# %%
plot_series(X_valid[0, :], y_valid[0], y_pred[0])
plt.show()

# %% [markdown]
# ## Linear predictions:

# %%
model = keras.models.Sequential([
    # keras.layers.Flatten(input_shape=[6, 1]),
    keras.layers.Dense(1,input_shape=[6]),
])

optimizer = keras.optimizers.Adam(learning_rate=0.01)

model.compile(loss="mse", optimizer=optimizer)
history = model.fit(
    X_train,
    y_train,
    epochs=80, #20
    batch_size=128, #128
    validation_data=(X_valid, y_valid),
)
# Out:
# Epoch 1/80
# 11/11 [==============================] - 1s 13ms/step - loss: 0.4516 - val_loss: 0.2174
# Epoch 2/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1056 - val_loss: 0.0447
# Epoch 3/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0422 - val_loss: 0.0409
# Epoch 4/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0457 - val_loss: 0.0356
# Epoch 5/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.0297
# Epoch 6/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0307 - val_loss: 0.0284
# Epoch 7/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0245
# Epoch 8/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0211
# Epoch 9/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0184
# Epoch 10/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0162
# Epoch 11/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0141
# Epoch 12/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.0122
# Epoch 13/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.0105
# Epoch 14/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0109 - val_loss: 0.0090
# Epoch 15/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0078
# Epoch 16/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0068
# Epoch 17/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 18/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 19/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 20/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 21/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 22/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 23/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 24/80
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 25/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 26/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 27/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 28/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 29/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 30/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 31/80
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 32/80
# 11/11 [==============================] - 0s 4ms/step - loss: 9.5636e-04 - val_loss: 9.6764e-04
# Epoch 33/80
# 11/11 [==============================] - 0s 4ms/step - loss: 8.7427e-04 - val_loss: 8.9694e-04
# Epoch 34/80
# 11/11 [==============================] - 0s 4ms/step - loss: 8.0255e-04 - val_loss: 8.5137e-04
# Epoch 35/80
# 11/11 [==============================] - 0s 3ms/step - loss: 7.4101e-04 - val_loss: 7.9587e-04
# Epoch 36/80
# 11/11 [==============================] - 0s 4ms/step - loss: 6.9223e-04 - val_loss: 7.6171e-04
# Epoch 37/80
# 11/11 [==============================] - 0s 5ms/step - loss: 6.5283e-04 - val_loss: 7.3508e-04
# Epoch 38/80
# 11/11 [==============================] - 0s 4ms/step - loss: 6.1622e-04 - val_loss: 7.0018e-04
# Epoch 39/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.8677e-04 - val_loss: 6.8173e-04
# Epoch 40/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.6235e-04 - val_loss: 6.6169e-04
# Epoch 41/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.4370e-04 - val_loss: 6.4612e-04
# Epoch 42/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.2736e-04 - val_loss: 6.3372e-04
# Epoch 43/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.1478e-04 - val_loss: 6.2227e-04
# Epoch 44/80
# 11/11 [==============================] - 0s 3ms/step - loss: 5.0327e-04 - val_loss: 6.1408e-04
# Epoch 45/80
# 11/11 [==============================] - 0s 3ms/step - loss: 4.9461e-04 - val_loss: 6.0628e-04
# Epoch 46/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.8692e-04 - val_loss: 5.9905e-04
# Epoch 47/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.8175e-04 - val_loss: 5.9388e-04
# Epoch 48/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.7674e-04 - val_loss: 5.8910e-04
# Epoch 49/80
# 11/11 [==============================] - 0s 3ms/step - loss: 4.7148e-04 - val_loss: 5.8509e-04
# Epoch 50/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.6796e-04 - val_loss: 5.8095e-04
# Epoch 51/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.6406e-04 - val_loss: 5.7784e-04
# Epoch 52/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.6180e-04 - val_loss: 5.7532e-04
# Epoch 53/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5931e-04 - val_loss: 5.7273e-04
# Epoch 54/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5753e-04 - val_loss: 5.7080e-04
# Epoch 55/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5545e-04 - val_loss: 5.6901e-04
# Epoch 56/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5397e-04 - val_loss: 5.6726e-04
# Epoch 57/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5247e-04 - val_loss: 5.6541e-04
# Epoch 58/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5227e-04 - val_loss: 5.6406e-04
# Epoch 59/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.5086e-04 - val_loss: 5.6236e-04
# Epoch 60/80
# 11/11 [==============================] - 0s 10ms/step - loss: 4.4963e-04 - val_loss: 5.6078e-04
# Epoch 61/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4879e-04 - val_loss: 5.6041e-04
# Epoch 62/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4715e-04 - val_loss: 5.5811e-04
# Epoch 63/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4578e-04 - val_loss: 5.5799e-04
# Epoch 64/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.4461e-04 - val_loss: 5.5588e-04
# Epoch 65/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.4390e-04 - val_loss: 5.5489e-04
# Epoch 66/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4295e-04 - val_loss: 5.5358e-04
# Epoch 67/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4302e-04 - val_loss: 5.5257e-04
# Epoch 68/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4141e-04 - val_loss: 5.5114e-04
# Epoch 69/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.4060e-04 - val_loss: 5.5366e-04
# Epoch 70/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3940e-04 - val_loss: 5.4884e-04
# Epoch 71/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3822e-04 - val_loss: 5.4911e-04
# Epoch 72/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3752e-04 - val_loss: 5.4722e-04
# Epoch 73/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3656e-04 - val_loss: 5.4553e-04
# Epoch 74/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3816e-04 - val_loss: 5.4448e-04
# Epoch 75/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3705e-04 - val_loss: 5.4391e-04
# Epoch 76/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.3631e-04 - val_loss: 5.4263e-04
# Epoch 77/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.3250e-04 - val_loss: 5.4101e-04
# Epoch 78/80
# 11/11 [==============================] - 0s 5ms/step - loss: 4.3314e-04 - val_loss: 5.4016e-04
# Epoch 79/80
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3180e-04 - val_loss: 5.3878e-04
# Epoch 80/80
# 11/11 [==============================] - 0s 4ms/step - loss: 4.3016e-04 - val_loss: 5.3873e-04

# %%
model.evaluate(X_valid, y_valid) #Erro medio quadratico
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 5.3873e-04
# 0.0005387323908507824

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.01072376],
#         [ 0.00173762],
#         [ 0.16298   ],
#         [ 0.4072483 ],
#         [-0.37318346],
#         [ 0.8086302 ]], dtype=float32),
#  array([-0.00792697], dtype=float32)]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :], y_valid[0], y_pred[0])
plt.show()
# Out:
# 12/12 [==============================] - 3s 1ms/step

# %% [markdown]
# ## Simple RNN

# %% [markdown]
# ###Validação 1

# %%
print(X_train.shape)
print(X_valid.shape)
X_train = X_train.reshape((1332,1,6))
X_valid = X_valid.reshape((380,1,6))
print(X_train.shape)
print(X_valid.shape)
# Out:
# (1332, 6)
# (380, 6)
# (1332, 1, 6)
# (380, 1, 6)

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None,6]),
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1)                 8
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(
    X_train,
    y_train,
    epochs=20, #20
    batch_size=180, #180
    validation_data=(X_valid, y_valid),
)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 1s 33ms/step - loss: 0.0232 - val_loss: 0.0029
# Epoch 2/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0089
# Epoch 3/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 4/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 5/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 6/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 7/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 8/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 9/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 10/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 11/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 12/20
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 13/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 14/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 15/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 16/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 17/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 18/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 19/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 20/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013

# %%
model.evaluate(X_valid, y_valid) #
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0013
# 0.0012514485279098153

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.05686105],
#         [ 0.01806545],
#         [ 0.74034745],
#         [-0.49327958],
#         [ 0.3950833 ],
#         [ 0.7119067 ]], dtype=float32),
#  array([[-1.]], dtype=float32),
#  array([-0.1325481], dtype=float32)]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)

X_valid = X_valid.reshape((380, 6))
plot_series(X_valid[0, :], y_valid[0], y_pred[0])
plt.title("RNN Validação 1")
plt.show()
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Validação 2

# %%
X_train = X_train.reshape((1332,1,6))
X_valid = X_valid.reshape((380,1,6))

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None,6]),
])

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(
    X_train,
    y_train,
    epochs=80, #20
    batch_size=180, #180
    validation_data=(X_valid, y_valid),
)
# Out:
# Epoch 1/80
# 8/8 [==============================] - 1s 32ms/step - loss: 0.2944 - val_loss: 0.1598
# Epoch 2/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0854 - val_loss: 0.0403
# Epoch 3/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0309 - val_loss: 0.0231
# Epoch 4/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0289 - val_loss: 0.0243
# Epoch 5/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0305 - val_loss: 0.0236
# Epoch 6/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0284 - val_loss: 0.0210
# Epoch 7/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0249 - val_loss: 0.0192
# Epoch 8/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0226 - val_loss: 0.0186
# Epoch 9/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 0.0180
# Epoch 10/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0170
# Epoch 11/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0156
# Epoch 12/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0144
# Epoch 13/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0164 - val_loss: 0.0134
# Epoch 14/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0152 - val_loss: 0.0125
# Epoch 15/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0142 - val_loss: 0.0116
# Epoch 16/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.0109
# Epoch 17/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0101
# Epoch 18/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0094
# Epoch 19/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0086
# Epoch 20/80
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0080
# Epoch 21/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 22/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 0.0068
# Epoch 23/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0063
# Epoch 24/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 25/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 26/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 27/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 28/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 29/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 30/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 31/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 32/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 33/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 34/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 35/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 36/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 37/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 38/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 39/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 40/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 41/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 42/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 43/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 44/80
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 45/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 46/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 47/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 48/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 49/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 50/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 51/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 52/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 53/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 54/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 55/80
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 56/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 57/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 58/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 59/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 60/80
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 61/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 62/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 63/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 64/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 65/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 66/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 67/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 68/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 69/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 70/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 71/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 72/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 73/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 74/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 75/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 76/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 77/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 78/80
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 79/80
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 80/80
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0015

# %%
model.evaluate(X_valid, y_valid) #
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0015
# 0.0015491923550143838

# %%
model.layers[0].get_weights()
# Out:
# [array([[0.0562207 ],
#         [0.0171683 ],
#         [0.54348767],
#         [0.36283046],
#         [0.0829289 ],
#         [0.3234599 ]], dtype=float32),
#  array([[1.]], dtype=float32),
#  array([-0.08881084], dtype=float32)]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)

X_valid = X_valid.reshape((380, 6))
plot_series(X_valid[0, :], y_valid[0], y_pred[0])
plt.title("RNN Validação 2")
plt.show()
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Teste

# %%
X_test = X_test.reshape((192,1,6))

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0014
# 0.0014460483798757195

# %%
y_pred = model.predict(X_test)

X_test = X_test.reshape((192, 6))
plot_series(X_test[0, :], y_test[0], y_pred[0])
plt.title("RNN teste")
plt.show()
# Out:
# 6/6 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Ano 2016 -> pais:

# %%
dataset_2016 = []
pais_lista=[]
maximo=0
for pais in lista_unica:
   data_pais = df[df["Country"] == pais]
   latitude_pais = data_pais.Lat
   latitude_pais = latitude_pais.tolist()
   latitude_pais = latitude_pais[0]
   longitude_pais = data_pais.Lon
   longitude_pais = longitude_pais.tolist()
   longitude_pais = longitude_pais[0]
   gdp =  data_pais.GDP
   gdp = gdp.tolist()
   gdp_1 = gdp[52]
   gdp_2 = gdp[53]
   gdp_3 = gdp[54]
   gdp_4 = gdp[55]
   gdp_5 = gdp[56]
   if math.isnan(gdp_1) or math.isnan(gdp_2) or math.isnan(gdp_3) or math.isnan(gdp_4) or math.isnan(gdp_5):
     nan = 0
      #  print(gdp_1[0])
      #  print("nan")
   else:
      if maximo < gdp_1 or maximo < gdp_2 or maximo < gdp_3 or maximo < gdp_4 or maximo < gdp_5:
        maximo = max(gdp_1,gdp_2,gdp_3,gdp_4,gdp_5)
      dataset_2016.append([latitude_pais, longitude_pais, gdp_1, gdp_2, gdp_3, gdp_4, gdp_5])
      pais_lista.append(pais)
      
      # dataset.append(dataset_array)

print(dataset_2016)
# Out:
# [[33.7680065, 66.2385139, 2.805396079015299, 2.7954040857303757, 2.7883263169355805, 2.7450804317977333, 2.7092807996512605], [41.000028, 19.9999619, 3.6281466843131116, 3.6447400295015084, 3.6607358538205137, 3.596905119739823, 3.6153244896255887], [28.000027199999998, 2.9999825, 3.747584257283366, 3.740330102845113, 3.7398140814530816, 3.6209569535610346, 3.5962068741310023], [42.540716700000004, 1.5732033, 4.587559005657684, 4.597044626022803, 4.615991369408493, 4.553528370251751, 4.5737490010980375], [-11.877576800000002, 17.5691241, 3.7075784384172983, 3.7205628960298847, 3.7330697436291755, 3.6198213986318604, 3.544820970182604], [17.223472100000002, -61.9554608, 4.122960421660318, 4.110946110552187, 4.130384623728254, 4.154890270536925, 4.181807670489101], [-34.9964963, -64.9672817, 4.116696198427254, 4.1166162017689025, 4.091132050329143, 4.139534674715464, 4.106878777769819], [40.7696272, 44.6736646, 3.566065464929581, 3.5841246455960003, 3.6005625301901993, 3.557180973404371, 3.5553155379727137], [-24.7761086, 134.755, 4.832686692484554, 4.83350809535004, 4.795961244283943, 4.753636841266036, 4.697941800815654], [47.2000338, 13.199959, 4.686347495111114, 4.705151061965992, 4.713637489032647, 4.6452065166098455, 4.655876026431734], [40.3936294, 47.787250799999995, 3.8748466484970883, 3.8962923052570706, 3.897149277640464, 3.7403871974177645, 3.588914405030701], [26.155124899999997, 50.5344606, 4.373911378163067, 4.393475119033846, 4.397756480961913, 4.354762954928612, 4.354270838036492], [24.4768783, 90.2932426, 2.9460183087556118, 2.992049944232086, 3.0487811073934603, 3.0963723050905436, 3.1466131306612737], [13.1500331, -59.52503050000001, 4.210844651250565, 4.216199675868392, 4.217196220620906, 4.2181388269368085, 4.227887945456822], [53.4250605, 27.6971358, 3.8421805063822254, 3.902988200258326, 3.9212389309367905, 3.7757598373655394, 3.7024031238678963], [50.6402809, 4.666714499999999, 4.6500462448466315, 4.669732028899291, 4.678523298832319, 4.612697075357218, 4.623084879166808], [16.8259793, -88.7600927, 3.653752690297744, 3.659787054571032, 3.6737981222308544, 3.6785395611357328, 3.6863657114517654], [9.5293472, 2.2584408, 3.0588586246819225, 3.097330126008872, 3.111064207180175, 3.0321337150585963, 3.0363443278846787], [27.549511, 90.5119273, 3.40465406607617, 3.3931757763626496, 3.4236104715740017, 3.4397478659874072, 3.466952828976296], [-17.056869600000002, -64.9912286, 3.416620632865516, 3.4636243254267236, 3.4888155586380667, 3.482297712487305, 3.4880790027184507], [44.305347600000005, 17.596146700000002, 3.6791613246135726, 3.7100888797110265, 3.7267561399756266, 3.674832672770527, 3.6985330190269914], [-23.1681782, 24.5928742, 3.848224442599668, 3.8588326060383866, 3.874784434984163, 3.8063774098150573, 3.844036910607331], [-10.333333300000001, -53.2, 4.092377537743383, 4.089918765446814, 4.083245799743739, 3.9451725439056005, 3.9400213107341515], [42.6073975, 25.4856617, 3.8711336771153384, 3.8854706066156792, 3.8977252569373584, 3.849706863565228, 3.879065977827321], [12.075308300000001, -1.6880313999999998, 2.8796694502649114, 2.896233707818747, 2.8991889695209956, 2.8151307848626503, 2.8377466594129013], [-3.3634357, 29.8870575, 2.4020185752511742, 2.4098919776933463, 2.439108123269043, 2.485081794139091, 2.4159164473540846], [16.0000552, -24.0083947, 3.537502145895704, 3.558232693828718, 3.5549281489977123, 3.483306431086918, 3.4956828947044762], [13.5066394, 104.869423, 2.9781258709394645, 3.005789700393333, 3.0388171890951674, 3.0655442358990093, 3.1036640057675875], [4.6125522000000005, 13.153581099999998, 3.1472195077231566, 3.184052649628824, 3.205262311534044, 3.14066821537521, 3.1502208246692605], [61.0666922, -107.9917071, 4.721555814515422, 4.721276070857797, 4.707195314649628, 4.639447994095821, 4.62650054122134], [7.0323598, 19.9981227, 2.752663869671633, 2.580123939975818, 2.627825649436647, 2.5768282676356415, 2.604433044601331], [15.613413699999999, 19.015617199999998, 2.98558495986 ...

# %%
my_array = np.array(dataset_2016)
dataset_2016 = my_array.astype('float32')
# Normalizando os Valores
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_2016 = scaler.fit_transform(dataset_2016)
dataset_2016
# Out:
# array([[0.706847  , 0.60706556, 0.14430475, ..., 0.12303579, 0.09494376,
#         0.10422927],
#        [0.77476335, 0.44595784, 0.43863642, ..., 0.43040127, 0.4060049 ,
#         0.42613715],
#        [0.65267956, 0.38672528, 0.48136413, ..., 0.4582619 , 0.41478777,
#         0.41934484],
#        ...,
#        [0.68492043, 0.4960546 , 0.38806224, ..., 0.38269132, 0.37603474,
#         0.40203303],
#        [0.25338447, 0.4722988 , 0.3020233 , ..., 0.2843216 , 0.2342453 ,
#         0.24570662],
#        [0.21641307, 0.47991863, 0.2552774 , ..., 0.25286287, 0.24641943,
#         0.26639587]], dtype=float32)

# %%
n_steps = 6
X_2016, y_2016 = dataset_2016[:, :n_steps], dataset_2016[:, -1]
# print(X_2016)
# print(y_2016)

# %%
y_2016.shape
# Out:
# (156,)

# %%
X_2016.shape
# Out:
# (156, 6)

# %%
X_2016 = X_2016.reshape((156,1,6))

# %%
print(model.evaluate(X_2016, y_2016))
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0023
# 0.0023326443042606115

# %%
y_pred = model.predict(X_2016)

X_2016 = X_2016.reshape((156, 6))
plot_series(X_2016[0, :], y_2016[0], y_pred[0])
plt.title("RNN 2016")
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
print(y_2016)
y_2016_pred = y_pred.reshape(156)
# y_2016_pred=[]
# for y in y_pred
# Out:
# [0.10422927 0.42613715 0.41934484 0.7666554  0.40108806 0.6274026
#  0.60078126 0.40481657 0.81077975 0.79583424 0.41675395 0.68867713
#  0.25960892 0.64377457 0.4570753  0.7841839  0.45137733 0.2204315
#  0.3734222  0.38092822 0.45570034 0.5073963  0.5414985  0.51984173
#  0.14987189 0.         0.38362974 0.24434954 0.26089066 0.78539747
#  0.06697798 0.1510331  0.6119862  0.5301866  0.4806283  0.5910849
#  0.31550056 0.59758145 0.5295455  0.7017407  0.82490593 0.36650866
#  0.529931   0.5138437  0.48552555 0.4137531  0.55078405 0.65591043
#  0.39750212 0.1562131  0.47474843 0.790662   0.7648403  0.5074294
#  0.4238041  0.7846368  0.31229275 0.652746   0.556963   0.4279688
#  0.15944248 0.14374512 0.47905964 0.24685568 0.33779103 0.60456055
#  0.84430665 0.29232174 0.40356523 0.4413256  0.8463617  0.76605564
#  0.7370836  0.45095664 0.7743848  0.42804474 0.5227768  0.27265638
#  0.41185898 0.7197556  0.61823505 0.52154976 0.16124886 0.42277616
#  0.9959672  0.6253523  0.92828757 0.09296143 0.02965438 0.5599709
#  0.55010086 0.16932422 0.708702   0.2738275  0.55781585 0.54210764
#  0.37075967 0.99999994 0.40764993 0.5084098  0.37162954 0.07690835
#  0.44120115 0.19117993 0.7983056  0.7770241  0.32255548 0.10063225
#  0.32748562 0.46040422 0.86407477 0.64260787 0.2559169  0.61847144
#  0.34949595 0.4655612  0.48917156 0.38077754 0.59658927 0.66959447
#  0.8318034  0.55568093 0.16204768 0.79081684 0.28940374 0.66882294
#  0.24438745 0.4778282  0.6260759  0.1010021  0.83095115 0.6820902
#  0.47760767 0.71321434 0.4169746  0.2179355  0.48068112 0.8170933
#  0.8894833  0.20226163 0.4838155  0.25425357 0.17369443 0.6377284
#  0.4184788  0.5760291  0.16033918 0.32831496 0.7693743  0.7823927
#  0.6420817  0.36104494 0.32862812 0.40203303 0.24570662 0.26639587]

# %%
data = {'Pais': pais_lista ,
        '2016':[(item * maximo) for item in y_2016] ,
         '2016 predição':[(item * maximo) for item in y_2016_pred],
        }

df = pd.DataFrame(data)
df
# Out:
#                    Pais      2016  2016 predição
# 0           Afghanistan  0.550065       0.681966
# 1               Albania  2.248919       2.543753
# 2               Algeria  2.213073       2.674156
# 3               Andorra  4.045989       3.961467
# 4                Angola  2.116724       2.551398
# ..                  ...       ...            ...
# 151          Uzbekistan  1.905398       2.079066
# 152             Vietnam  1.734320       1.776958
# 153  West Bank and Gaza  2.121711       2.288606
# 154              Zambia  1.296705       1.573119
# 155            Zimbabwe  1.405892       1.372868
#
# [156 rows x 3 columns]
